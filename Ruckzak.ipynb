# %% [markdown]
# <a href="https://colab.research.google.com/github/Ira-a02/Algorithm/blob/main/Ruckzak.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# put your python code here
W, n = map(int, input().split())
w = list(map(int, input().split()))
w.sort()
def func(W,n,w):
    arr=[[ 0 for i in range (W+1)]for j in range(n+1)]
    for i in range(1,n+1):
        for j in range (1,W+1):
            if w[i-1]>j:
                arr[i][j]=arr[i-1][j]
            else:
                arr[i][j]=max(arr[i-1][j],arr[i-1][j-w[i-1]]+w[i-1])
    return arr[n][W]
print(func(W,n,w))
