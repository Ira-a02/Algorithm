# %% [markdown]
# <a href="https://colab.research.google.com/github/Ira-a02/Algorithm/blob/main/Sortirovka_podschotom.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# put your python code here
n = int(input())

A = [[str(i), 0] for i in range(11)]

for key in input().split():
    A[int(key)][1] += 1

for element in A:
    if element[1] != 0:
        print('{} '.format(element[0]) * element[1], end='')
